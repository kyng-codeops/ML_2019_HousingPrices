# %%
a = 10
b = 2
c = 3

(a*c)/b
# Out:
# 15.0

# %%
(a*c)**b
# Out:
# 900

# %%
a = ['a1', 'a2', 'ab', 'a3']
b = ['b1', 'b2', 'ab', 'b3']

for i in a:
    for j in b:
        if i == j:
            print('the common elements are: {}'.format(i))
# Out:
# the common elements are: ab

# %%
a = ['a1', 'a2', 'ab', 'a3']
b = ['b1', 'b2', 'ab', 'b3']

# create statistical sets from lists a & b
set1 = set(a)
set2 = set(b)

set1.intersection(set2)
# Out:
# {'ab'}

# %%
set1 & set2
# Out:
# {'ab'}

# %%
# set1.difference(set2)
set1 - set2
# Out:
# {'a1', 'a2', 'a3'}

# %%
# set1.uionion(set2)
set1 | set2
# Out:
# {'a1', 'a2', 'a3', 'ab', 'b1', 'b2', 'b3'}

# %%
import numpy as np

a = 10
b = 2
c = 3

np.sqrt((a*c)**b)
# Out:
# 30.0

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')

print(df)
# Out:
#            Date   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0    2015-02-17  127.489998  128.880005  126.919998  127.830002     63152400
# 1    2015-02-18  127.629997  128.779999  127.449997  128.720001     44891700
# 2    2015-02-19  128.479996  129.029999  128.330002  128.449997     37362400
# 3    2015-02-20  128.619995  129.500000  128.050003  129.500000     48948400
# 4    2015-02-23  130.020004  133.000000  129.660004  133.000000     70974100
# ..          ...         ...         ...         ...         ...          ...
# 501  2017-02-10  132.460007  132.940002  132.050003  132.119995     20065500
# 502  2017-02-13  133.080002  133.820007  132.750000  133.289993     23035400
# 503  2017-02-14  133.470001  135.089996  133.250000  135.020004     32815500
# 504  2017-02-15  135.520004  136.270004  134.619995  135.509995     35501600
# 505  2017-02-16  135.669998  135.899994  134.839996  135.350006     22118000
#
#      AAPL.Adjusted          dn        mavg          up   direction
# 0       122.905254  106.741052  117.927667  129.114281  Increasing
# 1       123.760965  107.842423  118.940333  130.038244  Increasing
# 2       123.501363  108.894245  119.889167  130.884089  Decreasing
# 3       124.510914  109.785449  120.763500  131.741551  Increasing
# 4       127.876074  110.372516  121.720167  133.067817  Increasing
# ..             ...         ...         ...         ...         ...
# 501     132.119995  114.494004  124.498666  134.503328  Decreasing
# 502     133.289993  114.820798  125.205166  135.589534  Increasing
# 503     135.020004  115.175718  125.953499  136.731280  Increasing
# 504     135.509995  115.545035  126.723499  137.901963  Decreasing
# 505     135.350006  116.203299  127.504333  138.805366  Decreasing
#
# [506 rows x 11 columns]

# %%
# display(df)
df
# Out:
#            Date   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0    2015-02-17  127.489998  128.880005  126.919998  127.830002     63152400
# 1    2015-02-18  127.629997  128.779999  127.449997  128.720001     44891700
# 2    2015-02-19  128.479996  129.029999  128.330002  128.449997     37362400
# 3    2015-02-20  128.619995  129.500000  128.050003  129.500000     48948400
# 4    2015-02-23  130.020004  133.000000  129.660004  133.000000     70974100
# ..          ...         ...         ...         ...         ...          ...
# 501  2017-02-10  132.460007  132.940002  132.050003  132.119995     20065500
# 502  2017-02-13  133.080002  133.820007  132.750000  133.289993     23035400
# 503  2017-02-14  133.470001  135.089996  133.250000  135.020004     32815500
# 504  2017-02-15  135.520004  136.270004  134.619995  135.509995     35501600
# 505  2017-02-16  135.669998  135.899994  134.839996  135.350006     22118000
#
#      AAPL.Adjusted          dn        mavg          up   direction
# 0       122.905254  106.741052  117.927667  129.114281  Increasing
# 1       123.760965  107.842423  118.940333  130.038244  Increasing
# 2       123.501363  108.894245  119.889167  130.884089  Decreasing
# 3       124.510914  109.785449  120.763500  131.741551  Increasing
# 4       127.876074  110.372516  121.720167  133.067817  Increasing
# ..             ...         ...         ...         ...         ...
# 501     132.119995  114.494004  124.498666  134.503328  Decreasing
# 502     133.289993  114.820798  125.205166  135.589534  Increasing
# 503     135.020004  115.175718  125.953499  136.731280  Increasing
# 504     135.509995  115.545035  126.723499  137.901963  Decreasing
# 505     135.350006  116.203299  127.504333  138.805366  Decreasing
#
# [506 rows x 11 columns]

# %%
df.describe()
# Out:
#         AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close   AAPL.Volume  \
# count  506.000000  506.000000  506.000000  506.000000  5.060000e+02
# mean   112.935000  113.919447  111.942016  112.958340  4.317842e+07
# std     11.287490   11.251892   11.263687   11.244744  1.985253e+07
# min     90.000000   91.669998   89.470001   90.339996  1.147590e+07
# 25%    105.482500  106.349999  104.657501  105.672499  2.974240e+07
# 50%    112.889999  114.145001  111.800003  113.025002  3.747460e+07
# 75%    122.267498  123.497500  121.599998  122.179998  5.076395e+07
# max    135.669998  136.270004  134.839996  135.509995  1.622063e+08
#
#        AAPL.Adjusted          dn        mavg          up
# count     506.000000  506.000000  506.000000  506.000000
# mean      110.459312  107.311385  112.739865  118.168345
# std        10.537529   11.095804   10.595315   10.670752
# min        89.008370   85.508858   94.047166   97.572721
# 25%       103.484803   97.011245  104.954875  111.052267
# 50%       110.821123  107.351628  112.799750  118.472542
# 75%       119.255457  114.812152  121.889416  128.515793
# max       135.509995  127.289258  129.845000  138.805366

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           506 non-null    object
#  1   AAPL.Open      506 non-null    float64
#  2   AAPL.High      506 non-null    float64
#  3   AAPL.Low       506 non-null    float64
#  4   AAPL.Close     506 non-null    float64
#  5   AAPL.Volume    506 non-null    int64
#  6   AAPL.Adjusted  506 non-null    float64
#  7   dn             506 non-null    float64
#  8   mavg           506 non-null    float64
#  9   up             506 non-null    float64
#  10  direction      506 non-null    object
# dtypes: float64(8), int64(1), object(2)
# memory usage: 43.6+ KB

# %%
df['AAPL.Close']
# Out:
# 0      127.830002
# 1      128.720001
# 2      128.449997
# 3      129.500000
# 4      133.000000
#           ...
# 501    132.119995
# 502    133.289993
# 503    135.020004
# 504    135.509995
# 505    135.350006
# Name: AAPL.Close, Length: 506, dtype: float64

# %%
import plotly.graph_objects as go
import plotly.io as pio
from datetime import datetime

fig = go.Figure()
fig.add_trace(
    go.Candlestick(x=df['Date'], 
        open=df['AAPL.Open'], 
        high=df['AAPL.High'], 
        low=df['AAPL.Low'], 
        close=df['AAPL.Close'])
)
fig.show()

# %%
df['AAPL.Close'].pct_change(periods=1)*100
# Out:
# 0           NaN
# 1      0.696236
# 2     -0.209761
# 3      0.817441
# 4      2.702703
#          ...
# 501   -0.226554
# 502    0.885557
# 503    1.297930
# 504    0.362903
# 505   -0.118064
# Name: AAPL.Close, Length: 506, dtype: float64

# %%
df['%_chg_Close'] = df['AAPL.Close'].pct_change()*100

df
# Out:
#            Date   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0    2015-02-17  127.489998  128.880005  126.919998  127.830002     63152400
# 1    2015-02-18  127.629997  128.779999  127.449997  128.720001     44891700
# 2    2015-02-19  128.479996  129.029999  128.330002  128.449997     37362400
# 3    2015-02-20  128.619995  129.500000  128.050003  129.500000     48948400
# 4    2015-02-23  130.020004  133.000000  129.660004  133.000000     70974100
# ..          ...         ...         ...         ...         ...          ...
# 501  2017-02-10  132.460007  132.940002  132.050003  132.119995     20065500
# 502  2017-02-13  133.080002  133.820007  132.750000  133.289993     23035400
# 503  2017-02-14  133.470001  135.089996  133.250000  135.020004     32815500
# 504  2017-02-15  135.520004  136.270004  134.619995  135.509995     35501600
# 505  2017-02-16  135.669998  135.899994  134.839996  135.350006     22118000
#
#      AAPL.Adjusted          dn        mavg          up   direction  \
# 0       122.905254  106.741052  117.927667  129.114281  Increasing
# 1       123.760965  107.842423  118.940333  130.038244  Increasing
# 2       123.501363  108.894245  119.889167  130.884089  Decreasing
# 3       124.510914  109.785449  120.763500  131.741551  Increasing
# 4       127.876074  110.372516  121.720167  133.067817  Increasing
# ..             ...         ...         ...         ...         ...
# 501     132.119995  114.494004  124.498666  134.503328  Decreasing
# 502     133.289993  114.820798  125.205166  135.589534  Increasing
# 503     135.020004  115.175718  125.953499  136.731280  Increasing
# 504     135.509995  115.545035  126.723499  137.901963  Decreasing
# 505     135.350006  116.203299  127.504333  138.805366  Decreasing
#
#      %_chg_Close
# 0            NaN
# 1       0.696236
# 2      -0.209761
# 3       0.817441
# 4       2.702703
# ..           ...
# 501    -0.226554
# 502     0.885557
# 503     1.297930
# 504     0.362903
# 505    -0.118064
#
# [506 rows x 12 columns]

# %%
import plotly.graph_objects as go
import plotly.io as pio
from datetime import datetime

from plotly.subplots import make_subplots

fig = go.Figure()
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(
    go.Candlestick(x=df['Date'], 
        open=df['AAPL.Open'], 
        high=df['AAPL.High'], 
        low=df['AAPL.Low'], 
        close=df['AAPL.Close']), 
    secondary_y=False
)
fig.add_trace(
    go.Scatter(x=df['Date'], y=df['%_chg_Close'], mode='lines', opacity=0.1, marker_color='blue'), 
    secondary_y=True
)
fig.show()

# %%
df['%_chg_Close'] = df['AAPL.Close'].pct_change()*100
df['SMA7_%_chg_Close'] = df['%_chg_Close'].rolling(7).mean()

fig = go.Figure()
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(
    go.Candlestick(x=df['Date'], 
        open=df['AAPL.Open'], 
        high=df['AAPL.High'], 
        low=df['AAPL.Low'], 
        close=df['AAPL.Close']), 
    secondary_y=False
)
fig.add_trace(
    go.Scatter(x=df['Date'], y=df['SMA7_%_chg_Close'], mode='lines', opacity=0.1, marker_color='blue'), 
    secondary_y=True
)
fig.show()

# %%
df['%_chg_Close'] = df['AAPL.Close'].pct_change(periods=7)*100

fig = go.Figure()
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(
    go.Candlestick(x=df['Date'], 
        open=df['AAPL.Open'], 
        high=df['AAPL.High'], 
        low=df['AAPL.Low'], 
        close=df['AAPL.Close']), 
    secondary_y=False
)
fig.add_trace(
    go.Scatter(x=df['Date'], y=df['%_chg_Close'], mode='lines', opacity=0.1, marker_color='blue'), 
    secondary_y=True
)
fig.show()

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/yankev/testing/master/datasets/nycflights.csv')

print(f'row count = {len(df)}')
df.sample(10)
# Out:
# row count = 336776
#         Unnamed: 0  year  month  day  dep_time  dep_delay  arr_time  \
# 46295        46296  2013     10   21    1739.0       -2.0    1941.0
# 151241      151242  2013      3   17     849.0       -1.0    1137.0
# 124309      124310  2013      2   15    1858.0        3.0    2215.0
# 163412      163413  2013      3   29       NaN        NaN       NaN
# 294692      294693  2013      8   16    1106.0       -9.0    1229.0
# 93021        93022  2013     12   11    1459.0       39.0    1717.0
# 144465      144466  2013      3    9    2021.0       18.0      46.0
# 271485      271486  2013      7   23    1200.0       -9.0    1340.0
# 38069        38070  2013     10   12    1911.0        1.0    2212.0
# 242452      242453  2013      6   22    1430.0        0.0    1538.0
#
#         arr_delay carrier tailnum  flight origin dest  air_time  distance  \
# 46295        -3.0      EV  N14173    4667    EWR  MSP     150.0      1008
# 151241       -8.0      B6  N228JB      59    JFK  TPA     149.0      1005
# 124309      -25.0      VX  N626VA      29    JFK  SFO     342.0      2586
# 163412        NaN      US     NaN    2114    LGA  BOS       NaN       184
# 294692      -26.0      AA  N592AA     327    LGA  ORD     116.0       733
# 93021        33.0      UA  N565UA     624    EWR  DEN     235.0      1605
# 144465      -18.0      UA  N76529    1071    EWR  BQN     183.0      1585
# 271485       24.0      B6  N183JB    1191    JFK  ACK      45.0       199
# 38069        -3.0      AA  N324AA      21    JFK  LAX     320.0      2475
# 242452      -17.0      EV  N834AS    5713    LGA  IAD      43.0       229
#
#         hour  minute
# 46295   17.0    39.0
# 151241   8.0    49.0
# 124309  18.0    58.0
# 163412   NaN     NaN
# 294692  11.0     6.0
# 93021   14.0    59.0
# 144465  20.0    21.0
# 271485  12.0     0.0
# 38069   19.0    11.0
# 242452  14.0    30.0

# %%
df.drop(df.columns[0], axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 16 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   year       336776 non-null  int64
#  1   month      336776 non-null  int64
#  2   day        336776 non-null  int64
#  3   dep_time   328521 non-null  float64
#  4   dep_delay  328521 non-null  float64
#  5   arr_time   328063 non-null  float64
#  6   arr_delay  327346 non-null  float64
#  7   carrier    336776 non-null  object
#  8   tailnum    334264 non-null  object
#  9   flight     336776 non-null  int64
#  10  origin     336776 non-null  object
#  11  dest       336776 non-null  object
#  12  air_time   327346 non-null  float64
#  13  distance   336776 non-null  int64
#  14  hour       328521 non-null  float64
#  15  minute     328521 non-null  float64
# dtypes: float64(7), int64(5), object(4)
# memory usage: 41.1+ MB

# %%
df.dropna(axis='index', how='any', inplace=True)
df.drop_duplicates(inplace=True)

df
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     544.0       -1.0    1004.0      -18.0      B6
# 4       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 336765  2013      9   30    2240.0       -5.0    2334.0      -17.0      B6
# 336766  2013      9   30    2240.0      -10.0    2347.0      -20.0      B6
# 336767  2013      9   30    2241.0       -5.0    2345.0      -16.0      B6
# 336768  2013      9   30    2307.0       12.0    2359.0        1.0      B6
# 336769  2013      9   30    2349.0      -10.0     325.0      -25.0      B6
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# 0       N14228    1545    EWR  IAH     227.0      1400   5.0    17.0
# 1       N24211    1714    LGA  IAH     227.0      1416   5.0    33.0
# 2       N619AA    1141    JFK  MIA     160.0      1089   5.0    42.0
# 3       N804JB     725    JFK  BQN     183.0      1576   5.0    44.0
# 4       N668DN     461    LGA  ATL     116.0       762   5.0    54.0
# ...        ...     ...    ...  ...       ...       ...   ...     ...
# 336765  N354JB    1816    JFK  SYR      41.0       209  22.0    40.0
# 336766  N281JB    2002    JFK  BUF      52.0       301  22.0    40.0
# 336767  N346JB     486    JFK  ROC      47.0       264  22.0    41.0
# 336768  N565JB     718    JFK  BOS      33.0       187  23.0     7.0
# 336769  N516JB     745    JFK  PSE     196.0      1617  23.0    49.0
#
# [327346 rows x 16 columns]

# %%
a = df.carrier.unique()

a
# Out:
# array(['UA', 'AA', 'B6', 'DL', 'EV', 'MQ', 'US', 'WN', 'VX', 'FL', 'AS',
#        '9E', 'F9', 'HA', 'YV', 'OO'], dtype=object)

# %%
len(a)
# Out:
# 16

# %%
b = list((range(101, 101 + len(a), 1)))

b
# Out:
# [101,
#  102,
#  103,
#  104,
#  105,
#  106,
#  107,
#  108,
#  109,
#  110,
#  111,
#  112,
#  113,
#  114,
#  115,
#  116]

# %%
carrier_codes = dict(zip(a, b))

carrier_codes
# Out:
# {'UA': 101,
#  'AA': 102,
#  'B6': 103,
#  'DL': 104,
#  'EV': 105,
#  'MQ': 106,
#  'US': 107,
#  'WN': 108,
#  'VX': 109,
#  'FL': 110,
#  'AS': 111,
#  '9E': 112,
#  'F9': 113,
#  'HA': 114,
#  'YV': 115,
#  'OO': 116}

# %%
df['carrier'] = df.carrier.map(carrier_codes)

df.sample(10)
# Out:
#         Unnamed: 0  year  month  day  dep_time  dep_delay  arr_time  \
# 115963      115964  2013      2    6    1319.0       49.0    1539.0
# 153396      153397  2013      3   19    1358.0       -1.0    1626.0
# 73642        73643  2013     11   20     827.0       -3.0     946.0
# 157271      157272  2013      3   23    1443.0       -2.0    1708.0
# 167470      167471  2013      4    3    1259.0       -1.0    1427.0
# 257438      257439  2013      7    8    1953.0       -7.0    2150.0
# 182259      182260  2013      4   19     551.0       -9.0     646.0
# 100750      100751  2013     12   19    2148.0       34.0    2330.0
# 136695      136696  2013      3    1    1348.0       48.0    1514.0
# 237892      237893  2013      6   17    1948.0       23.0    2308.0
#
#         arr_delay  carrier tailnum  flight origin dest  air_time  distance  \
# 115963       40.0      105  N14959    3826    EWR  ATL     118.0       746
# 153396       -6.0      104  N346NB    2043    JFK  ATL     128.0       760
# 73642       -27.0      112  N272PQ    2926    JFK  ORD     117.0       740
# 157271       -2.0      106  N542MQ    4669    LGA  ATL     124.0       762
# 167470        2.0      108  N789SW    3295    EWR  BNA     126.0       748
# 257438       38.0      107  N958UW    2142    LGA  BOS      37.0       184
# 182259      -13.0      107  N757UW    2161    LGA  DCA      40.0       214
# 100750       19.0      105  N13161    4700    EWR  CLT      83.0       529
# 136695       34.0      102  N578AA     329    LGA  ORD     120.0       733
# 237892       51.0      101  N33266    1555    EWR  SAN     337.0      2425
#
#         hour  minute
# 115963  13.0    19.0
# 153396  13.0    58.0
# 73642    8.0    27.0
# 157271  14.0    43.0
# 167470  12.0    59.0
# 257438  19.0    53.0
# 182259   5.0    51.0
# 100750  21.0    48.0
# 136695  13.0    48.0
# 237892  19.0    48.0
